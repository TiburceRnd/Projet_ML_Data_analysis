# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('boston_house_prices.xlsx')

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston = data.copy()

# %%
boston.shape
# Out:
# (506, 14)

# %%
boston['AGE'].max()
# Out:
# 100.0

# %%
plt.figure(figsize=(20,10))
sns.heatmap(boston.isna(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
boston.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %% [markdown]
# ## Analyse de Fond :
# ###### Analyse de Target(MEDV)

# %%
boston['MEDV'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64

# %% [markdown]
# ### histogrames des variables continues

# %%
for col in boston.select_dtypes('float'):#de -4 à 2(continu)
    plt.figure()
    sns.distplot(boston[col])
# Out:
# /home/bob/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/bob/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Histogramme des variables quantitatives

# %%
for col in boston.select_dtypes('int64'):#de -4 à 2(continu)
    plt.figure()
    sns.distplot(boston[col])
# Out:
# /home/bob/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/bob/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
boston['CHAS'].describe()
# Out:
# count    506.000000
# mean       0.069170
# std        0.253994
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: CHAS, dtype: float64

# %%
boston['CHAS'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: CHAS, dtype: int64

# %%
boston['RAD'].describe()
# Out:
# count    506.000000
# mean       9.549407
# std        8.707259
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%       24.000000
# max       24.000000
# Name: RAD, dtype: float64

# %%
boston['TAX'].describe()
# Out:
# count    506.000000
# mean     408.237154
# std      168.537116
# min      187.000000
# 25%      279.000000
# 50%      330.000000
# 75%      666.000000
# max      711.000000
# Name: TAX, dtype: float64

# %%
boston['RM'].describe()
# Out:
# count    506.000000
# mean       6.284634
# std        0.702617
# min        3.561000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max        8.780000
# Name: RM, dtype: float64

# %%
sns.distplot(boston['MEDV'],rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3 },norm_hist=True,)
# Out:
# /home/bob/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MEDV', ylabel='Density'>

# %%
boston['MEDV'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64

# %%
boston['MEDV'].value_counts()
# Out:
# 50.0    16
# 25.0     8
# 23.1     7
# 21.7     7
# 22.0     7
#         ..
# 12.8     1
# 29.9     1
# 9.6      1
# 36.1     1
# 13.0     1
# Name: MEDV, Length: 229, dtype: int64

# %%
sns.pairplot(boston)

# %%
boston_df = boston.drop(['CRIM','ZN','CHAS','NOX','B'],axis=1)

# %%
sns.pairplot(boston_df)

# %%
boston_df

# %%
sns.heatmap(pd.crosstab(boston['SARS-Cov-2 exam result'], df[col]), annot=True, fmt='d')

# %%
sns.heatmap(pd.crosstab(boston['AGE'], boston['MEDV']), annot=True, fmt='d')

# %%
boston_df.corr()

# %%
sns.heatmap(boston_df.corr())

# %%
sns.clustermap(boston_df.corr())

# %%
plt.scatter(boston_df['MEDV'],boston_df['RM'],s = 5)
plt.xlabel("Prices")
plt.ylabel("average number of Room per dwelling RM")

# %% [markdown]
# # Model

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.linear_model import LinearRegression

# %%
X = (boston_df['MEDV']).reshape((506,1))

# %%
X = np.array(boston_df['MEDV']).reshape((506,1))

# %%
X.shape

# %%
y = np.array(boston_df['RM']).reshape((506,1))

# %%
y.shape

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
model = make_pipeline(RobustScaler(), LinearRegression())

# %%
model.get_params()

# %%
model.fit(X_train, y_train)
model.score(X_test, y_test)

# %%
predictions = model.predict(X) #y pour le model
#predictions
plt.scatter(X,y)
plt.plot(X,predictions,c='r')

# %%
boston_df['RM']

# %%
sns.jointplot('MEDV','RM',data = boston_df,kind='kde')

# %%
sns.jointplot('MEDV','RM',data = boston_df)

# %%
predict = model.predict(X_test)

# %%
#Precision Recall Curve

# %%
from sklearn.metrics import precision_recall_curve

# %%
precision_recall_curve(y_test[0],predict[0])
