# %%
# !conda install -c conda-forge hdf5=1.10.5

# %%
from sklearn import datasets

# %%
import os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
#   File "<ipython-input-5-ba804015d654>", line 1
#     import os.environ['KMP_DUPLICATE_LIB_OK']='True'
#                      ^
# SyntaxError: invalid syntax

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-64156d691fe5> in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
print("hello")
# Out:
# hello

# %%
pip install tensorflow

# %%
from sklearn import datasets
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#telecharger la bdd
df = datasets.load_breast_cancer()

#decouvrir la bdd
print(df.DESCR) #ou .info

df.data #heterogene

#preparer les données
X = df.data
y = df.target

#standardisation
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled

#decoupage
X_train,X_test,y_train,y_test = train_test_split(X_sclaled,y,test_size = 0.2,random_state = 42)

#construction de reseau de neurone
#Creation du reseau de neurone

# %%
model = tf.keras.models.Sequential()
